# %%
import pandas as pd

df = pd.read_csv('/Users/atulyaagrawal/Desktop/steam_top_games_2026.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1495 entries, 0 to 1494
# Data columns (total 29 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   app_id                1495 non-null   int64
#  1   name                  1495 non-null   object
#  2   release_date          1488 non-null   object
#  3   coming_soon           1495 non-null   bool
#  4   price_usd             1495 non-null   float64
#  5   is_free               1495 non-null   bool
#  6   discount_pct          1495 non-null   int64
#  7   developer             1487 non-null   object
#  8   publisher             1483 non-null   object
#  9   genres                1487 non-null   object
#  10  categories            1486 non-null   object
#  11  tags                  1489 non-null   object
#  12  platforms_win         1495 non-null   bool
#  13  platforms_mac         1495 non-null   bool
#  14  platforms_linux       1495 non-null   bool
# ...

# %%
df.head(5)
# Out:
#    app_id                        name  release_date  coming_soon  price_usd  \
# 0  794260  Outward Definitive Edition  May 17, 2022        False       4.79
# 1  253920                    Gorky 17  Sep 27, 2013        False       9.99
# 2  613010             Secret in Story  Jun 19, 2017        False       0.89
# 3  892420                       懒人修仙传  Nov 14, 2018        False       3.99
# 4  914010    Train Station Renovation   Oct 1, 2020        False      18.99
#
#    is_free  discount_pct            developer  \
# 0    False            88     Nine Dots Studio
# 1    False             0  Metropolis Software
# 2    False            10           Naivus Luo
# 3    False             0                托更的修罗
# 4    False             0    Live Motion Games
#
#                                            publisher  \
# 0                          Prime Matter, Deep Silver
# 1                                TopWare Interactive
# 2                                         Naivus Luo
# ...

# %%
print(len(df))
# Out:
# 1495

# %%
print(df.columns)
# Out:
# Index(['app_id', 'name', 'release_date', 'coming_soon', 'price_usd', 'is_free',
#        'discount_pct', 'developer', 'publisher', 'genres', 'categories',
#        'tags', 'platforms_win', 'platforms_mac', 'platforms_linux',
#        'metacritic_score', 'recommendations', 'positive_reviews',
#        'negative_reviews', 'estimated_owners', 'avg_playtime_forever',
#        'avg_playtime_2weeks', 'median_playtime', 'peak_ccu', 'required_age',
#        'dlc_count', 'achievements', 'short_description', 'header_image'],
#       dtype='object')

# %%
print(df.dtypes)
# Out:
# app_id                    int64
# name                     object
# release_date             object
# coming_soon                bool
# price_usd               float64
# is_free                    bool
# discount_pct              int64
# developer                object
# publisher                object
# genres                   object
# categories               object
# tags                     object
# platforms_win              bool
# platforms_mac              bool
# platforms_linux            bool
# metacritic_score        float64
# recommendations           int64
# positive_reviews          int64
# negative_reviews          int64
# estimated_owners         object
# avg_playtime_forever      int64
# avg_playtime_2weeks       int64
# median_playtime           int64
# peak_ccu                  int64
# required_age              int64
# dlc_count                 int64
# achievements              int64
# short_description        object
# header_image             object
# ...

# %%
df.head(10)
# Out:
#     app_id                             name  release_date  coming_soon  \
# 0   794260       Outward Definitive Edition  May 17, 2022        False
# 1   253920                         Gorky 17  Sep 27, 2013        False
# 2   613010                  Secret in Story  Jun 19, 2017        False
# 3   892420                            懒人修仙传  Nov 14, 2018        False
# 4   914010         Train Station Renovation   Oct 1, 2020        False
# 5   352550                     Urban Empire  Jan 20, 2017        False
# 6   247020          Cook, Serve, Delicious!   Oct 8, 2013        False
# 7   253940                    Septerra Core  Sep 27, 2013        False
# 8  1846170                        Iron Lung   Mar 9, 2022        False
# 9   260210  Assassin’s Creed® Liberation HD  Jan 15, 2014        False
#
#    price_usd  is_free  discount_pct            developer  \
# 0       4.79    False            88     Nine Dots Studio
# 1       9.99    False             0  Metropolis Software
# ...

# %%
df.isnull().sum()
# Out:
# app_id                  0
# name                    0
# release_date            0
# coming_soon             0
# price_usd               0
# is_free                 0
# discount_pct            0
# developer               0
# publisher               0
# genres                  0
# categories              0
# tags                    0
# platforms_win           0
# platforms_mac           0
# platforms_linux         0
# metacritic_score        0
# recommendations         0
# positive_reviews        0
# negative_reviews        0
# estimated_owners        0
# avg_playtime_forever    0
# avg_playtime_2weeks     0
# median_playtime         0
# peak_ccu                0
# required_age            0
# dlc_count               0
# achievements            0
# short_description       0
# header_image            0
# dtype: int64

# %%
df.head(5)
# Out:
#     app_id                                   name  release_date  coming_soon  \
# 4   914010               Train Station Renovation   Oct 1, 2020        False
# 5   352550                           Urban Empire  Jan 20, 2017        False
# 11   34330                    Total War: SHOGUN 2  Mar 15, 2011        False
# 13  736260                            Baba Is You  Mar 13, 2019        False
# 15  350640  Sherlock Holmes: The Devil's Daughter  Jun 10, 2016        False
#
#     price_usd  is_free  discount_pct  \
# 4       18.99    False             0
# 5        2.99    False            90
# 11       5.99    False            80
# 13      14.99    False             0
# 15       2.99    False            90
#
#                                             developer  \
# 4                                   Live Motion Games
# 5                                        Reborn Games
# 11  CREATIVE ASSEMBLY, Feral Interactive (Mac), Fe...
# ...

# %%
print(df['price_usd'].mean())
# Out:
# 16.274800000000003

# %%
print('Maximum price: ', df['price_usd'].max())
print('Minimum price: ', df['price_usd'].min())
# Out:
# Maximum price:  69.99
# Minimum price:  0.0

# %%
df.head(5)
# Out:
#     app_id                                   name  release_date  coming_soon  \
# 4   914010               Train Station Renovation   Oct 1, 2020        False
# 5   352550                           Urban Empire  Jan 20, 2017        False
# 11   34330                    Total War: SHOGUN 2  Mar 15, 2011        False
# 13  736260                            Baba Is You  Mar 13, 2019        False
# 15  350640  Sherlock Holmes: The Devil's Daughter  Jun 10, 2016        False
#
#     price_usd  is_free  discount_pct  \
# 4       18.99    False             0
# 5        2.99    False            90
# 11       5.99    False            80
# 13      14.99    False             0
# 15       2.99    False            90
#
#                                             developer  \
# 4                                   Live Motion Games
# 5                                        Reborn Games
# 11  CREATIVE ASSEMBLY, Feral Interactive (Mac), Fe...
# ...

# %%
df['is_free'].sum()
# Out:
# np.int64(22)

# %%
df.sort_values('price_usd',ascending=False).head(1)
# Out:
#       app_id                            name  release_date  coming_soon  \
# 155  2072450  Like a Dragon: Infinite Wealth  Jan 25, 2024        False
#
#      price_usd  is_free  discount_pct             developer publisher  \
# 155      69.99    False             0  Ryu Ga Gotoku Studio      SEGA
#
#                      genres  ...      estimated_owners avg_playtime_forever  \
# 155  Action, Adventure, RPG  ...  500,000 .. 1,000,000                 3635
#
#      avg_playtime_2weeks  median_playtime  peak_ccu  required_age  dlc_count  \
# 155                   63             2029       655            17         19
#
#      achievements                                  short_description  \
# 155            74  Two larger-than-life heroes, Ichiban Kasuga an...
#
#                                           header_image
# 155  https://shared.akamai.steamstatic.com/store_it...
#
# [1 rows x 29 columns]

# %%
df.sort_values('price_usd',ascending=True).head(1)
# Out:
#      app_id                                     name  release_date  \
# 200  255420  Magic 2015 - Duels of the Planeswalkers  Jul 16, 2014
#
#      coming_soon  price_usd  is_free  discount_pct        developer  \
# 200        False        0.0    False             0  Stainless Games
#
#                 publisher    genres  ...    estimated_owners  \
# 200  Wizards of the Coast  Strategy  ...  200,000 .. 500,000
#
#     avg_playtime_forever  avg_playtime_2weeks  median_playtime  peak_ccu  \
# 200                 1535                    0              301         2
#
#      required_age  dlc_count  achievements  \
# 200             0          0            35
#
#                                      short_description  \
# 200  &quot;Hunt bigger game on a bold new adventure...
#
#                                           header_image
# 200  https://shared.akamai.steamstatic.com/store_it...
#
# [1 rows x 29 columns]

# %%
df[df['price_usd'] > 50]
# Out:
#        app_id                                            name  release_date  \
# 73    2677660              Indiana Jones and the Great Circle   Dec 8, 2024
# 155   2072450                  Like a Dragon: Infinite Wealth  Jan 25, 2024
# 193   1086940                                 Baldur's Gate 3   Aug 3, 2023
# 232    814380       Sekiro™: Shadows Die Twice - GOTY Edition  Mar 21, 2019
# 361   1382330                             Persona® 5 Strikers  Feb 22, 2021
# 771   1778820                                        TEKKEN 8  Jan 25, 2024
# 822    209650  Call of Duty®: Advanced Warfare - Gold Edition   Nov 3, 2014
# 1134   916440                                       Anno 1800  Apr 16, 2019
# 1220   924970                                    Back 4 Blood  Oct 12, 2021
# 1252   544750                                  SOULCALIBUR VI  Oct 18, 2018
# 1255  1771300                    Kingdom Come: Deliverance II   Feb 4, 2025
# ...

# %%
df[df['is_free'] == True]
# Out:
#       app_id                                       name  release_date  \
# 101   200390                                   Oil Rush  Jan 25, 2012
# 216     9880                           Champions Online  Jun 14, 2011
# 355   298260                                    Only If  Jul 25, 2014
# 564   377300                           Thunder Tier One   Dec 7, 2021
# 608   386360                                     SMITE®   Sep 8, 2015
# 610   230410                                   Warframe  Mar 25, 2013
# 663    24200                        DC Universe™ Online   Nov 2, 2011
# 664   311730  DEAD OR ALIVE 5 Last Round: Core Fighters  Mar 30, 2015
# 701     9900                           Star Trek Online  Jan 31, 2012
# 739   212070                              Star Conflict  Feb 27, 2013
# 811   298520                               Orbital Gear   Aug 7, 2014
# 864   225600                             Blade Symphony   May 7, 2014
# ...

# %%
df.head(5)
# Out:
#     app_id                                   name  release_date  coming_soon  \
# 4   914010               Train Station Renovation   Oct 1, 2020        False
# 5   352550                           Urban Empire  Jan 20, 2017        False
# 11   34330                    Total War: SHOGUN 2  Mar 15, 2011        False
# 13  736260                            Baba Is You  Mar 13, 2019        False
# 15  350640  Sherlock Holmes: The Devil's Daughter  Jun 10, 2016        False
#
#     price_usd  is_free  discount_pct  \
# 4       18.99    False             0
# 5        2.99    False            90
# 11       5.99    False            80
# 13      14.99    False             0
# 15       2.99    False            90
#
#                                             developer  \
# 4                                   Live Motion Games
# 5                                        Reborn Games
# 11  CREATIVE ASSEMBLY, Feral Interactive (Mac), Fe...
# ...

# %%
df.columns
# Out:
# Index(['app_id', 'name', 'release_date', 'coming_soon', 'price_usd', 'is_free',
#        'discount_pct', 'developer', 'publisher', 'genres', 'categories',
#        'tags', 'platforms_win', 'platforms_mac', 'platforms_linux',
#        'metacritic_score', 'recommendations', 'positive_reviews',
#        'negative_reviews', 'estimated_owners', 'avg_playtime_forever',
#        'avg_playtime_2weeks', 'median_playtime', 'peak_ccu', 'required_age',
#        'dlc_count', 'achievements', 'short_description', 'header_image'],
#       dtype='object')

# %%
df.sort_values('positive_reviews',ascending=True)
# Out:
#        app_id                        name  release_date  coming_soon  \
# 967    283390  Incoming + Incoming Forces   Mar 6, 2014        False
# 583      2840      X: Beyond the Frontier   Oct 8, 2010        False
# 1180     8880               Freedom Force  May 29, 2009        False
# 101    200390                    Oil Rush  Jan 25, 2012        False
# 954    237950             UFO: Afterlight   Jan 6, 2014        False
# ...       ...                         ...           ...          ...
# 960    239140                 Dying Light  Jan 26, 2015        False
# 610    230410                    Warframe  Mar 25, 2013        False
# 1228   346110       ARK: Survival Evolved  Aug 27, 2017        False
# 193   1086940             Baldur's Gate 3   Aug 3, 2023        False
# 578    252490                        Rust   Feb 8, 2018        False
#
#       price_usd  is_free  discount_pct  \
# 967        2.99    False             0
# 583        4.99    False             0
# ...

# %%
df['release_date'] = pd.to_datetime(df['release_date'])

# %%
df[df['release_date'].dt.year > 2023]
# Out:
#        app_id                                  name release_date  coming_soon  \
# 73    2677660    Indiana Jones and the Great Circle   2024-12-08        False
# 116   1903340           Clair Obscur: Expedition 33   2025-04-24        False
# 155   2072450        Like a Dragon: Infinite Wealth   2024-01-25        False
# 260   1422440                            Cataclismo   2025-03-20        False
# 314   1025600            Battle Realms: Zen Edition   2025-01-27        False
# 323   2273430               BlazBlue Entropy Effect   2024-02-14        False
# 326   1062810                              Inkbound   2024-04-09        False
# 438   2488620                                F1® 24   2024-05-31        False
# 567   1735700                      Back to the Dawn   2025-07-17        False
# 603   1601580                           Frostpunk 2   2024-09-20        False
# 679   1466060     Tainted Grail: The Fall of Avalon   2025-05-23        False
# ...

# %%
df.head(1)
# Out:
#    app_id                      name release_date  coming_soon  price_usd  \
# 4  914010  Train Station Renovation   2020-10-01        False      18.99
#
#    is_free  discount_pct          developer  \
# 4    False             0  Live Motion Games
#
#                                            publisher  \
# 4  Live Motion Games, Frozen Way, PlayWay S.A., F...
#
#                       genres  ...    estimated_owners avg_playtime_forever  \
# 4  Casual, Indie, Simulation  ...  200,000 .. 500,000                  448
#
#    avg_playtime_2weeks  median_playtime  peak_ccu  required_age  dlc_count  \
# 4                    0              201        16             0          1
#
#    achievements                                  short_description  \
# 4            73  Welcome to an old, ruined train station. A pla...
#
#                                         header_image
# 4  https://shared.akamai.steamstatic.com/store_it...
#
# [1 rows x 29 columns]

# %%
df.groupby('genres')['price_usd'].mean()
# Out:
# genres
# Action                                                                                              18.235088
# Action, Adventure                                                                                   23.014286
# Action, Adventure, Casual                                                                           11.240000
# Action, Adventure, Casual, Indie                                                                    14.490000
# Action, Adventure, Casual, Indie, Massively Multiplayer, RPG, Simulation, Strategy, Free To Play     0.000000
#                                                                                                       ...
# Simulation, Sports                                                                                   0.000000
# Simulation, Strategy                                                                                19.008750
# ...

# %%
df.groupby('genres')['price_usd'].mean().max()
# Out:
# 49.99

# %%
df.groupby('genres')['name'].count()
# Out:
# genres
# Action                                                                                              57
# Action, Adventure                                                                                   42
# Action, Adventure, Casual                                                                            4
# Action, Adventure, Casual, Indie                                                                     2
# Action, Adventure, Casual, Indie, Massively Multiplayer, RPG, Simulation, Strategy, Free To Play     1
#                                                                                                     ..
# Simulation, Sports                                                                                   3
# Simulation, Strategy                                                                                16
# Sports                                                                                               1
# ...

# %%
df.groupby('genres')['name'].count().sort_values(ascending=False)
# Out:
# genres
# Action                                                                                              57
# Action, Adventure                                                                                   42
# Adventure, Indie                                                                                    27
# Action, Adventure, Indie                                                                            26
# Action, Indie                                                                                       25
#                                                                                                     ..
# Adventure, Indie, Massively Multiplayer, RPG, Strategy                                               1
# Action, Adventure, Casual, Indie, Massively Multiplayer, RPG, Simulation, Strategy, Free To Play     1
# Adventure, Indie, RPG, Simulation                                                                    1
# ...

# %%
df.sort_values('price_usd',ascending=False).head(5)
# Out:
#        app_id                                            name release_date  \
# 155   2072450                  Like a Dragon: Infinite Wealth   2024-01-25
# 73    2677660              Indiana Jones and the Great Circle   2024-12-08
# 1220   924970                                    Back 4 Blood   2021-10-12
# 822    209650  Call of Duty®: Advanced Warfare - Gold Edition   2014-11-03
# 361   1382330                             Persona® 5 Strikers   2021-02-22
#
#       coming_soon  price_usd  is_free  discount_pct  \
# 155         False      69.99    False             0
# 73          False      69.99    False             0
# 1220        False      59.99    False             0
# 822         False      59.99    False             0
# 361         False      59.99    False             0
#
#                                developer           publisher  \
# 155                 Ryu Ga Gotoku Studio                SEGA
# 73                          MachineGames  Bethesda Softworks
# ...

# %%
df.columns
# Out:
# Index(['app_id', 'name', 'release_date', 'coming_soon', 'price_usd', 'is_free',
#        'discount_pct', 'developer', 'publisher', 'genres', 'categories',
#        'tags', 'platforms_win', 'platforms_mac', 'platforms_linux',
#        'metacritic_score', 'recommendations', 'positive_reviews',
#        'negative_reviews', 'estimated_owners', 'avg_playtime_forever',
#        'avg_playtime_2weeks', 'median_playtime', 'peak_ccu', 'required_age',
#        'dlc_count', 'achievements', 'short_description', 'header_image'],
#       dtype='object')

# %%
df.sort_values('positive_reviews',ascending=False).head(5)
# Out:
#        app_id                   name release_date  coming_soon  price_usd  \
# 578    252490                   Rust   2018-02-08        False      39.99
# 193   1086940        Baldur's Gate 3   2023-08-03        False      59.99
# 1228   346110  ARK: Survival Evolved   2017-08-27        False       9.89
# 610    230410               Warframe   2013-03-25        False       0.00
# 960    239140            Dying Light   2015-01-26        False      24.99
#
#       is_free  discount_pct  \
# 578     False             0
# 193     False             0
# 1228    False            34
# 610      True             0
# 960     False             0
#
#                                               developer  \
# 578                                   Facepunch Studios
# 193                                      Larian Studios
# 1228  Studio Wildcard, Instinct Games, Efecto Studio...
# 610                                    Digital Extremes
# 960                                            Techland
#
# ...
